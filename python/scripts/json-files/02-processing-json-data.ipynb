# %% [markdown]
# ## Processing JSON data file using Python

# %%
import json

# %%
file_path = '../../../resources/data/retail_db/schemas.json'

# %%
schemas = json.load(open(file_path, 'r'))

# %%
schemas['orders']
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
# get_column_names(schemas, 'orders', 'column_name') =>
# ['order_customer_id' , 'order_date' , 'order_id' , 'order_status']

# %% [markdown]
# ##  Extract Details from Complex JSON Arrays using Python

# %%
column_details = schemas['orders']

# %%
[col['column_name'] for col in column_details]  # not sorted
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
map(lambda col: col['column_name'], column_details)

# %%
# make upper cell readable => pass to list
list(map(lambda col: col['column_name'], column_details))
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %% [markdown]
# ## Sort Data in JSON Arrays using Python

# %%
column_details
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
sorted(column_details) # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sorted(column_details)
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %%
sorted(column_details, key=lambda col: col['column_name'])  # ASC order
# Out:
# [{'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4}]

# %%
sorting_key = input('Enter sorting key: ')

# %%
sorted(column_details, key=lambda col: col[sorting_key])  # ASC order sorted by data_type
# Out:
# [{'column_name': 'order_id', 'data_type': 'integer', 'column_position': 1},
#  {'column_name': 'order_date', 'data_type': 'string', 'column_position': 2},
#  {'column_name': 'order_status', 'data_type': 'string', 'column_position': 4},
#  {'column_name': 'order_customer_id',
#   'data_type': 'timestamp',
#   'column_position': 3}]

# %%
columns = sorted(column_details, key=lambda col: col[sorting_key])

# %%
[col['column_name'] for col in columns]
# Out:
# ['order_id', 'order_date', 'order_status', 'order_customer_id']

# %% [markdown]
# ## Create Function to get Column Details from Schemas JSON File

# %%
def get_column_names(schemas, ds_name, sorting_key='column_position'):
    # default sorting key = column_position
    column_details = schemas[ds_name]
    columns = sorted(column_details, key=lambda col: col[sorting_key])
    return [col['column_name'] for col in columns]

# %%
get_column_names(schemas, 'orders', 'column_name')
# Out:
# ['order_customer_id', 'order_date', 'order_id', 'order_status']
