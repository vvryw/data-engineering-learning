# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ## Run cell by sequence

# %%
a = 10

# %%
b = 20

# %%
res = a + b

# %%
res
# Out:
# 30

# %% [markdown]
# ## Time sleep

# %%
import time

# %%
time.sleep(5)

# execute for 5 seconds

# %% [markdown]
# ## Function

# %%
def sumN(n):
    return (n * (n + 1)) / 2

# %%
sumN(5)
# Out:
# 15.0

# %% [markdown]
# ## Run cell by line

# %%
l = [1, 'Hello', None, 2, 4]

res = 0

for i in l:
    if type(i) == int:
        res += 1

res
# Out:
# 3
