# %% [markdown]
# # Simple Exercises for Filtering and Aggregations

# %% [markdown]
# ### Load SQL extension

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %env DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db
# Out:
# env: DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db

# %% [markdown]
# ### Create Table to Query

# %%
# %%sql
#
# DROP TABLE IF EXISTS courses;
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# CREATE TABLE courses (
#     course_id SERIAL PRIMARY KEY,
#     course_name VARCHAR(60),
#     course_author VARCHAR(40),
#     course_status VARCHAR(9),
#     course_published_dt DATE
# );
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# INSERT INTO courses
#     (course_name, course_author, course_status, course_published_dt)
# VALUES
#     ('Programming using Python', 'Bob Dillon', 'published', '2020-09-30'),
#     ('Data Engineering using Python', 'Bob Dillon', 'published', '2020-07-15'),
#     ('Data Engineering using Scala', 'Elvis Presley', 'draft', null),
#     ('Programming using Scala' , 'Elvis Presley' , 'published' , '2020-05-12'),
#     ('Programming using Java' , 'Mike Jack' , 'inactive' , '2020-08-10'),
#     ('Web Applications - Python Flask' , 'Bob Dillon' , 'inactive' , '2020-07-20'),
#     ('Web Applications - Java Spring' , 'Bob Dillon' , 'draft' , null),
#     ('Pipeline Orchestration - Python' , 'Bob Dillon' , 'draft' , null),
#     ('Streaming Pipelines - Python' , 'Bob Dillon' , 'published' , '2020-10-05'),
#     ('Web Applications - Scala Play' , 'Elvis Presley' , 'inactive' , '2020-09-30'),
#     ('Web Applications - Python Django' , 'Bob Dillon' , 'published' , '2020-06-23'),
#     ('Server Automation - Ansible' , 'Uncle Sam' , 'published' , '2020-07-05');
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 12 rows affected.
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# SELECT * FROM courses ORDER BY course_id;
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 12 rows affected.
# +-----------+---------------------------------+---------------+---------------+---------------------+
# | course_id |           course_name           | course_author | course_status | course_published_dt |
# +-----------+---------------------------------+---------------+---------------+---------------------+
# |     1     |     Programming using Python    |   Bob Dillon  |   published   |      2020-09-30     |
# |     2     |  Data Engineering using Python  |   Bob Dillon  |   published   |      2020-07-15     |
# |     3     |   Data Engineering using Scala  | Elvis Presley |     draft     |         None        |
# |     4     |     Programming using Scala     | Elvis Presley |   published   |      2020-05-12     |
# |     5     |      Programming using Java     |   Mike Jack   |    inactive   |      2020-08-10     |
# ...

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### 1. Get all the details of the courses which are in `inactive` or `draft` state.

# %%
# %%sql
#
# SELECT *
# FROM courses
# WHERE course_status IN ('inactive' , 'draft');
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 6 rows affected.
# +-----------+---------------------------------+---------------+---------------+---------------------+
# | course_id |           course_name           | course_author | course_status | course_published_dt |
# +-----------+---------------------------------+---------------+---------------+---------------------+
# |     3     |   Data Engineering using Scala  | Elvis Presley |     draft     |         None        |
# |     5     |      Programming using Java     |   Mike Jack   |    inactive   |      2020-08-10     |
# |     6     | Web Applications - Python Flask |   Bob Dillon  |    inactive   |      2020-07-20     |
# |     7     |  Web Applications - Java Spring |   Bob Dillon  |     draft     |         None        |
# |     8     | Pipeline Orchestration - Python |   Bob Dillon  |     draft     |         None        |
# ...

# %% [markdown]
# ### 2. Get all the details of the courses which are related to `Python` or `Scala`.

# %%
# %%sql
#
# SELECT *
# FROM courses
# WHERE course_name LIKE '%Python%' or course_name LIKE '%Scala%';
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 9 rows affected.
# +-----------+----------------------------------+---------------+---------------+---------------------+
# | course_id |           course_name            | course_author | course_status | course_published_dt |
# +-----------+----------------------------------+---------------+---------------+---------------------+
# |     1     |     Programming using Python     |   Bob Dillon  |   published   |      2020-09-30     |
# |     2     |  Data Engineering using Python   |   Bob Dillon  |   published   |      2020-07-15     |
# |     3     |   Data Engineering using Scala   | Elvis Presley |     draft     |         None        |
# |     4     |     Programming using Scala      | Elvis Presley |   published   |      2020-05-12     |
# |     6     | Web Applications - Python Flask  |   Bob Dillon  |    inactive   |      2020-07-20     |
# ...

# %% [markdown]
# ### 3. Get count of courses by `course_status`. The output should contain `course_status` and `course_count`.

# %%
# %%sql
#
# SELECT course_status, COUNT(*) AS couse_count
# FROM courses
# GROUP BY 1;
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 3 rows affected.
# +---------------+-------------+
# | course_status | couse_count |
# +---------------+-------------+
# |   published   |      6      |
# |    inactive   |      3      |
# |     draft     |      3      |
# +---------------+-------------+

# %% [markdown]
# ### 4. Get count of `published` courses by `course_author`. The output should contain `course_author` and `course_count`.

# %%
# %%sql
#
# SELECT course_author, COUNT(*) AS course_count
# FROM courses
# WHERE course_status = 'published'
# GROUP BY 1;
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 3 rows affected.
# +---------------+--------------+
# | course_author | course_count |
# +---------------+--------------+
# |   Bob Dillon  |      4       |
# | Elvis Presley |      1       |
# |   Uncle Sam   |      1       |
# +---------------+--------------+

# %% [markdown]
# ### 5. Get all the details of `Python` or `Scala` related courses in `draft` status.

# %%
# %%sql
#
# SELECT *
# FROM courses
# WHERE
#     (course_name LIKE '%Python%' OR course_name LIKE '%Scala%')
#     AND (course_status = 'draft');
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 2 rows affected.
# +-----------+---------------------------------+---------------+---------------+---------------------+
# | course_id |           course_name           | course_author | course_status | course_published_dt |
# +-----------+---------------------------------+---------------+---------------+---------------------+
# |     3     |   Data Engineering using Scala  | Elvis Presley |     draft     |         None        |
# |     8     | Pipeline Orchestration - Python |   Bob Dillon  |     draft     |         None        |
# +-----------+---------------------------------+---------------+---------------+---------------------+

# %% [markdown]
# ### 6. Get the author and count where the author have more than **one published** course. The output should contain `course_author` and `course_count`.

# %%
# %%sql
#
# SELECT course_author, COUNT(*) AS course_count
# FROM courses
# WHERE course_status = 'published'
# GROUP BY 1
# HAVING COUNT(*) > 1;
# Out:
# Running query in 'postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db'
# 1 rows affected.
# +---------------+--------------+
# | course_author | course_count |
# +---------------+--------------+
# |   Bob Dillon  |      4       |
# +---------------+--------------+
